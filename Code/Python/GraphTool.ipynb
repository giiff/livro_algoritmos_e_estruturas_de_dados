# %%
from graph_tool.all import *

# %%
g = Graph(directed = False)
v_prop = g.new_vertex_property("string")

v1 = g.add_vertex()
v2 = g.add_vertex()
v3 = g.add_vertex()
v4 = g.add_vertex()

v_prop[v1] = 'Paciente 01'
v_prop[v2] = 'Paciente 02'
v_prop[v3] = 'Brasil'
v_prop[v4] = 'Argentina'

e = g.add_edge(v1, v3)
e = g.add_edge(v2, v3)
e = g.add_edge(v2, v4)

graph_draw(g, vertex_text = v_prop, vertex_font_size = 10)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f034c168d30, at 0x7f0345e2f048>

# %%
is_biparitite, part = is_bipartite(g, partition = True)
graph_draw(g, vertex_fill_color = part, vertex_text = v_prop, vertex_font_size=10)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f034c168d30, at 0x7f034c164588>

# %%
g2 = lattice([50,50])
graph_draw(g2)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f0345e26cf8, at 0x7f034c168438>

# %%
is_biparitite, part = is_bipartite(g2, partition = True)
graph_draw(g2, vertex_fill_color = part)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f0345e26cf8, at 0x7f0345e3cc88>
